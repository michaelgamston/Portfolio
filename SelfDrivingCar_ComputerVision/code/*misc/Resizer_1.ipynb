# %%
import os
from PIL import Image

def resize_and_save_images(source_folder, destination_folder, target_size=(224, 224)):
    # Ensure the destination folder exists
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    # Loop through all files in the source folder
    for filename in os.listdir(source_folder):
        file_path = os.path.join(source_folder, filename)
        
        # Skip non-image files
        if not filename.lower().endswith(('.png')):
            continue
        
        try:
            # Open the image
            with Image.open(file_path) as img:
                # Convert to RGB (if necessary)
                img = img.convert("RGB")
                
                # Resize while preserving aspect ratio
                # img.thumbnail(target_size, Image.ANTIALIAS)

                img.thumbnail(target_size, Image.Resampling.LANCZOS)
                
                # Create a canvas of the target size and paste the resized image onto it (centered)
                new_img = Image.new("RGB", target_size, (0, 0, 0))  # Black background
                paste_position = ((target_size[0] - img.size[0]) // 2,
                                  (target_size[1] - img.size[1]) // 2)
                new_img.paste(img, paste_position)
                
                # Save the resized image to the destination folder
                save_path = os.path.join(destination_folder, filename)
                new_img.save(save_path, "JPEG", optimize=True)
                
                print(f"Resized and saved: {save_path}")
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

# Define source and destination folders
source_folder = 'data/training_data/training_data'  # Replace with your source folder path
destination_folder = 'data/training_data/training_data_resized'  # Replace with your destination folder path

# Run the resizing function
resize_and_save_images(source_folder, destination_folder, target_size=(224, 224))
# Out:
# Resized and saved: data/training_data/training_data_resized/3975.png
# Resized and saved: data/training_data/training_data_resized/8820.png
# Resized and saved: data/training_data/training_data_resized/9280.png
# Resized and saved: data/training_data/training_data_resized/348.png
# Resized and saved: data/training_data/training_data_resized/12085.png
# Resized and saved: data/training_data/training_data_resized/1804.png
# Resized and saved: data/training_data/training_data_resized/10692.png
# Resized and saved: data/training_data/training_data_resized/11598.png
# Resized and saved: data/training_data/training_data_resized/4968.png
# Resized and saved: data/training_data/training_data_resized/10686.png
# Resized and saved: data/training_data/training_data_resized/9294.png
# Resized and saved: data/training_data/training_data_resized/12091.png
# Resized and saved: data/training_data/training_data_resized/1810.png
# Resized and saved: data/training_data/training_data_resized/6819.png
# Resized and saved: data/training_data/training_data_resized/8834.png
# Resized and saved: data/training_data/training_data_resized/3961.png
# Resized and saved: data/training_data/training_data_resized/6831.png
# Resized and saved: data/training_data/training_data_resized/1186.png
# Resized and saved: data/training_data/training_data_resized/412.png
# Resized and saved: data/training_data/training_data_resized/12907.png
# Resized and saved: data/training_data/training_data_resized/3949.png
# Resized and saved: data/training_data/training_data_resized/3791.png
# Resized and saved: data/training_data/training_data_resized/10876.png
# Resized and saved: data/training_data/training_data_resized/4798.png
# Resized and saved: data/training_data/training_data_resized/4940.png
# Resized and saved: data/training_data/training_data_resized/5486.png
# Resized and saved: data/training_data/training_data_resized/374.png
# Resized and saved: data/training_data/training_data_resized/1838.png
# Resized and saved: data/training_data/training_data_resized/7291.png
# Resized and saved: data/training_data/training_data_resized/360.png
# Resized and saved: data/training_data/training_data_resized/7285.png
# Resized and saved: data/training_data/training_data_resized/10862.png
# Resized and saved: data/training_data/training_data_resized/4954.png
# Resized and saved: data/training_data/training_data_resized/5492.png
# Resized and saved: data/training_data/training_data_resized/3785.png
# Resized and saved: data/training_data/training_data_resized/6825.png
# Resized and saved: data/training_data/training_data_resized/8808.png
# Resized and saved: data/training_data/training_data_resized/406.png
# Resized and saved: data/training_data/training_data_resized/1192.png
# Resized and saved: data/training_data/training_data_resized/12913.png
# Resized and saved: data/training_data/training_data_resized/1179.png
# Resized and saved: data/training_data/training_data_resized/6616.png
# Resized and saved: data/training_data/training_data_resized/9525.png
# Resized and saved: data/training_data/training_data_resized/7508.png
# Resized and saved: data/training_data/training_data_resized/12720.png
# Resized and saved: data/training_data/training_data_resized/11229.png
# Resized and saved: data/training_data/training_data_resized/4001.png
# Resized and saved: data/training_data/training_data_resized/2470.png
# Resized and saved: data/training_data/training_data_resized/10137.png
# Resized and saved: data/training_data/training_data_resized/2316.png
# Resized and saved: data/training_data/training_data_resized/10651.png
# Resized and saved: data/training_data/training_data_resized/5479.png
# Resized and saved: data/training_data/training_data_resized/4767.png
# Resized and saved: data/training_data/training_data_resized/10889.png
# Resized and saved: data/training_data/training_data_resized/3008.png
# Resized and saved: data/training_data/training_data_resized/12046.png
# Resized and saved: data/training_data/training_data_resized/6170.png
# Resized and saved: data/training_data/training_data_resized/9243.png
# Resized and saved: data/training_data/training_data_resized/13358.png
# Resized and saved: data/training_data/training_data_resized/12052.png
# Resized and saved: data/training_data/training_data_resized/8149.png
# Resized and saved: data/training_data/training_data_resized/6164.png
# Resized and saved: data/training_data/training_data_resized/9257.png
# Resized and saved: data/training_data/training_data_resized/2302.png
# Resized and saved: data/training_data/training_data_resized/10645.png
# Resized and saved: data/training_data/training_data_resized/4773.png
# Resized and saved: data/training_data/training_data_resized/4015.png
# Resized and saved: data/training_data/training_data_resized/2464.png
# Resized and saved: data/training_data/training_data_resized/10123.png
# Resized and saved: data/training_data/training_data_resized/6602.png
# Resized and saved: data/training_data/training_data_resized/9531.png
# Resized and saved: data/training_data/training_data_resized/12734.png
# Resized and saved: data/training_data/training_data_resized/11215.png
# Resized and saved: data/training_data/training_data_resized/3752.png
# Resized and saved: data/training_data/training_data_resized/5323.png
# Resized and saved: data/training_data/training_data_resized/1145.png
# Resized and saved: data/training_data/training_data_resized/13402.png
# Resized and saved: data/training_data/training_data_resized/9519.png
# Resized and saved: data/training_data/training_data_resized/8607.png
# Resized and saved: data/training_data/training_data_resized/7534.png
# Resized and saved: data/training_data/training_data_resized/8161.png
# Resized and saved: data/training_data/training_data_resized/7252.png
# Resized and saved: data/training_data/training_data_resized/1623.png
# Resized and saved: data/training_data/training_data_resized/13364.png
# Resized and saved: data/training_data/training_data_resized/4983.png
# Resized and saved: data/training_data/training_data_resized/5445.png
# Resized and saved: data/training_data/training_data_resized/11573.png
# Resized and saved: data/training_data/training_data_resized/3034.png
# Resized and saved: data/training_data/training_data_resized/10679.png
# Resized and saved: data/training_data/training_data_resized/4997.png
# Resized and saved: data/training_data/training_data_resized/5451.png
# Resized and saved: data/training_data/training_data_resized/11567.png
# Resized and saved: data/training_data/training_data_resized/3020.png
# Resized and saved: data/training_data/training_data_resized/8175.png
# Resized and saved: data/training_data/training_data_resized/7246.png
# Resized and saved: data/training_data/training_data_resized/6158.png
# Resized and saved: data/training_data/training_data_resized/1637.png
# Resized and saved: data/training_data/training_data_resized/13370.png
# Resized and saved: data/training_data/training_data_resized/1151.png
# Resized and saved: data/training_data/training_data_resized/13416.png
# Resized and saved: data/training_data/training_data_resized/8613.png
# Resized and saved: data/training_data/training_data_resized/7520.png
# Resized and saved: data/training_data/training_data_resized/12708.png
# Resized and saved: data/training_data/training_data_resized/11201.png
# Resized and saved: data/training_data/training_data_resized/3746.png
# Resized and saved: data/training_data/training_data_resized/4029.png
# Resized and saved: data/training_data/training_data_resized/5337.png
# Resized and saved: data/training_data/training_data_resized/2458.png
# Resized and saved: data/training_data/training_data_resized/11956.png
# Resized and saved: data/training_data/training_data_resized/10490.png
# Resized and saved: data/training_data/training_data_resized/5860.png
# Resized and saved: data/training_data/training_data_resized/12287.png
# Resized and saved: data/training_data/training_data_resized/13199.png
# Resized and saved: data/training_data/training_data_resized/9082.png
# Resized and saved: data/training_data/training_data_resized/7911.png
# Resized and saved: data/training_data/training_data_resized/2869.png
# Resized and saved: data/training_data/training_data_resized/638.png
# Resized and saved: data/training_data/training_data_resized/7905.png
# Resized and saved: data/training_data/training_data_resized/9928.png
# Resized and saved: data/training_data/training_data_resized/8388.png
# Resized and saved: data/training_data/training_data_resized/12293.png
# Resized and saved: data/training_data/training_data_resized/9096.png
# Resized and saved: data/training_data/training_data_resized/11942.png
# Resized and saved: data/training_data/training_data_resized/10484.png
# Resized and saved: data/training_data/training_data_resized/5874.png
# Resized and saved: data/training_data/training_data_resized/7093.png
# Resized and saved: data/training_data/training_data_resized/176.png
# Resized and saved: data/training_data/training_data_resized/5684.png
# Resized and saved: data/training_data/training_data_resized/2855.png
# Resized and saved: data/training_data/training_data_resized/3593.png
# Resized and saved: data/training_data/training_data_resized/88.png
# Resized and saved: data/training_data/training_data_resized/610.png
# Resized and saved: data/training_data/training_data_resized/1384.png
# Resized and saved: data/training_data/training_data_resized/9900.png
# Resized and saved: data/training_data/training_data_resized/7939.png
# Resized and saved: data/training_data/training_data_resized/1390.png
# Resized and saved: data/training_data/training_data_resized/604.png
# Resized and saved: data/training_data/training_data_resized/9914.png
# Resized and saved: data/training_data/training_data_resized/2841.png
# Resized and saved: data/training_data/training_data_resized/3587.png
# Resized and saved: data/training_data/training_data_resized/2699.png
# Resized and saved: data/training_data/training_data_resized/5690.png
# Resized and saved: data/training_data/training_data_resized/5848.png
# Resized and saved: data/training_data/training_data_resized/7087.png
# Resized and saved: data/training_data/training_data_resized/162.png
# Resized and saved: data/training_data/training_data_resized/6399.png
# Resized and saved: data/training_data/training_data_resized/189.png
# Resized and saved: data/training_data/training_data_resized/9041.png
# Resized and saved: data/training_data/training_data_resized/6372.png
# Resized and saved: data/training_data/training_data_resized/12244.png
# Resized and saved: data/training_data/training_data_resized/4565.png
# Resized and saved: data/training_data/training_data_resized/11995.png
# Resized and saved: data/training_data/training_data_resized/10453.png
# Resized and saved: data/training_data/training_data_resized/2114.png
# Resized and saved: data/training_data/training_data_resized/10335.png
# Resized and saved: data/training_data/training_data_resized/2672.png
# Resized and saved: data/training_data/training_data_resized/4203.png
# Resized and saved: data/training_data/training_data_resized/12522.png
# Resized and saved: data/training_data/training_data_resized/837.png
# Resized and saved: data/training_data/training_data_resized/8439.png
# Resized and saved: data/training_data/training_data_resized/9727.png
# Resized and saved: data/training_data/training_data_resized/77.png
# Resized and saved: data/training_data/training_data_resized/6414.png
# Resized and saved: data/training_data/training_data_resized/12536.png
# Resized and saved: data/training_data/training_data_resized/823.png
# Resized and saved: data/training_data/training_data_resized/9733.png
# Resized and saved: data/training_data/training_data_resized/6400.png
# Resized and saved: data/training_data/training_data_resized/63.png
# Resized and saved: data/training_data/training_data_resized/13628.png
# Resized and saved: data/training_data/training_data_resized/10321.png
# Resized and saved: data/training_data/training_data_resized/2666.png
# Resized and saved: data/training_data/training_data_resized/5109.png
# Resized and saved: data/training_data/training_data_resized/4217.png
# Resized and saved: data/training_data/training_data_resized/3578.png
# Resized and saved: data/training_data/training_data_resized/11759.png
# Resized and saved: data/training_data/training_data_resized/4571.png
# Resized and saved: data/training_data/training_data_resized/11981.png
# Resized and saved: data/training_data/training_data_resized/10447.png
# Resized and saved: data/training_data/training_data_resized/2100.png
# Resized and saved: data/training_data/training_data_resized/1409.png
# Resized and saved: data/training_data/training_data_resized/9055.png
# Resized and saved: data/training_data/training_data_resized/6366.png
# Resized and saved: data/training_data/training_data_resized/7078.png
# Resized and saved: data/training_data/training_data_resized/12250.png
# Resized and saved: data/training_data/training_data_resized/3236.png
# Resized and saved: data/training_data/training_data_resized/11771.png
# Resized and saved: data/training_data/training_data_resized/4559.png
# Resized and saved: data/training_data/training_data_resized/5647.png
# Resized and saved: data/training_data/training_data_resized/2128.png
# Resized and saved: data/training_data/training_data_resized/13166.png
# Resized and saved: data/training_data/training_data_resized/1421.png
# Resized and saved: data/training_data/training_data_resized/7050.png
# Resized and saved: data/training_data/training_data_resized/8363.png
# Resized and saved: data/training_data/training_data_resized/12278.png
# Resized and saved: data/training_data/training_data_resized/7736.png
# Resized and saved: data/training_data/training_data_resized/8405.png
# Resized and saved: data/training_data/training_data_resized/6428.png
# Resized and saved: data/training_data/training_data_resized/13600.png
# Resized and saved: data/training_data/training_data_resized/1347.png
# Resized and saved: data/training_data/training_data_resized/10309.png
# Resized and saved: data/training_data/training_data_resized/5121.png
# Resized and saved: data/training_data/training_data_resized/2896.png
# Resized and saved: data/training_data/training_data_resized/3550.png
# Resized and saved: data/training_data/training_data_resized/11017.png
# Resized and saved: data/training_data/training_data_resized/5135.png
# Resized and saved: data/training_data/training_data_resized/2882.png
# Resized and saved: data/training_data/training_data_resized/3544.png
# Resized and saved: data/training_data/training_data_resized/11003.png
# Resized and saved: data/training_data/training_data_resized/7722.png
# Resized and saved: data/training_data/training_data_resized/8411.png
# Resized and saved: data/training_data/training_data_resized/13614.png
# Resized and saved: data/training_data/training_data_resized/1353.png
# Resized and saved: data/training_data/training_data_resized/13172.png
# Resized and saved: data/training_data/training_data_resized/1435.png
# Resized and saved: data/training_data/training_data_resized/9069.png
# Resized and saved: data/training_data/training_data_resized/7044.png
# Resized and saved: data/training_data/training_data_resized/8377.png
# Resized and saved: data/training_data/training_data_resized/3222.png
# Resized and saved: data/training_data/training_data_resized/11765.png
# Resized and saved: data/training_data/training_data_resized/5653.png
# Resized and saved: data/training_data/training_data_resized/5914.png
# Resized and saved: data/training_data/training_data_resized/11822.png
# Resized and saved: data/training_data/training_data_resized/980.png
# Resized and saved: data/training_data/training_data_resized/9848.png
# Resized and saved: data/training_data/training_data_resized/12495.png
# Resized and saved: data/training_data/training_data_resized/758.png
# Resized and saved: data/training_data/training_data_resized/7865.png
# Resized and saved: data/training_data/training_data_resized/9690.png
# Resized and saved: data/training_data/training_data_resized/10282.png
# Resized and saved: data/training_data/training_data_resized/10296.png
# Resized and saved: data/training_data/training_data_resized/11188.png
# Resized and saved: data/training_data/training_data_resized/2909.png
# Resized and saved: data/training_data/training_data_resized/994.png
# Resized and saved: data/training_data/training_data_resized/12481.png
# Resized and saved: data/training_data/training_data_resized/7871.png
# Resized and saved: data/training_data/training_data_resized/9684.png
# Resized and saved: data/training_data/training_data_resized/5900.png
# Resized and saved: data/training_data/training_data_resized/11836.png
# Resized and saved: data/training_data/training_data_resized/1596.png
# Resized and saved: data/training_data/training_data_resized/3381.png
# Resized and saved: data/training_data/training_data_resized/5928.png
# Resized and saved: data/training_data/training_data_resized/5096.png
# Resized and saved: data/training_data/training_data_resized/2921.png
# Resized and saved: data/training_data/training_data_resized/4388.png
# Resized and saved: data/training_data/training_data_resized/7681.png
# Resized and saved: data/training_data/training_data_resized/9874.png
# Resized and saved: data/training_data/training_data_resized/7859.png
# Resized and saved: data/training_data/training_data_resized/764.png
# Resized and saved: data/training_data/training_data_resized/7695.png
# Resized and saved: data/training_data/training_data_resized/9860.png
# Resized and saved: data/training_data/training_data_resized/770.png
# Resized and saved: data/training_data/training_data_resized/5082.png
# Resized and saved: data/training_data/training_data_resized/2935.png
# Resized and saved: data/training_data/training_data_resized/3395.png
# Resized and saved: data/training_data/training_data_resized/1582.png
# Resized and saved: data/training_data/training_data_resized/12330.png
# Resized and saved: data/training_data/training_data_resized/7118.png
# Resized and saved: data/training_data/training_data_resized/9135.png
# Resized and saved: data/training_data/training_data_resized/6206.png
# Resized and saved: data/training_data/training_data_resized/1569.png
# Resized and saved: data/training_data/training_data_resized/10527.png
# Resized and saved: data/training_data/training_data_resized/2060.png
# Resized and saved: data/training_data/training_data_resized/4411.png
# Resized and saved: data/training_data/training_data_resized/11639.png
# Resized and saved: data/training_data/training_data_resized/3418.png
# Resized and saved: data/training_data/training_data_resized/4377.png
# Resized and saved: data/training_data/training_data_resized/5069.png
# Resized and saved: data/training_data/training_data_resized/10241.png
# Resized and saved: data/training_data/training_data_resized/2706.png
# Resized and saved: data/training_data/training_data_resized/13748.png
# Resized and saved: data/training_data/training_data_resized/9653.png
# Resized and saved: data/training_data/training_data_resized/6560.png
# Resized and saved: data/training_data/training_data_resized/943.png
# Resized and saved: data/training_data/training_data_resized/12456.png
# Resized and saved: data/training_data/training_data_resized/9647.png
# Resized and saved: data/training_data/training_data_resized/6574.png
# Resized and saved: data/training_data/training_data_resized/957.png
# Resized and saved: data/training_data/training_data_resized/8559.png
# Resized and saved: data/training_data/training_data_resized/12442.png
# Resized and saved: data/training_data/training_data_resized/4363.png
# Resized and saved: data/training_data/training_data_resized/10255.png
# Resized and saved: data/training_data/training_data_resized/2712.png
# Resized and saved: data/training_data/training_data_resized/10533.png
# Resized and saved: data/training_data/training_data_resized/2074.png
# Resized and saved: data/training_data/training_data_resized/4405.png
# Resized and saved: data/training_data/training_data_resized/12324.png
# Resized and saved: data/training_data/training_data_resized/9121.png
# Resized and saved: data/training_data/training_data_resized/6212.png
# Resized and saved: data/training_data/training_data_resized/5733.png
# Resized and saved: data/training_data/training_data_resized/3342.png
# Resized and saved: data/training_data/training_data_resized/11605.png
# Resized and saved: data/training_data/training_data_resized/7124.png
# Resized and saved: data/training_data/training_data_resized/8217.png
# Resized and saved: data/training_data/training_data_resized/9109.png
# Resized and saved: data/training_data/training_data_resized/13012.png
# Resized and saved: data/training_data/training_data_resized/1555.png
# Resized and saved: data/training_data/training_data_resized/13774.png
# Resized and saved: data/training_data/training_data_resized/1233.png
# Resized and saved: data/training_data/training_data_resized/7642.png
# Resized and saved: data/training_data/training_data_resized/8571.png
# Resized and saved: data/training_data/training_data_resized/3424.png
# Resized and saved: data/training_data/training_data_resized/11163.png
# Resized and saved: data/training_data/training_data_resized/5055.png
# Resized and saved: data/training_data/training_data_resized/3430.png
# Resized and saved: data/training_data/training_data_resized/11177.png
# Resized and saved: data/training_data/training_data_resized/5041.png
# Resized and saved: data/training_data/training_data_resized/10269.png
# Resized and saved: data/training_data/training_data_resized/13760.png
# Resized and saved: data/training_data/training_data_resized/1227.png
# Resized and saved: data/training_data/training_data_resized/6548.png
# Resized and saved: data/training_data/training_data_resized/7656.png
# Resized and saved: data/training_data/training_data_resized/8565.png
# Resized and saved: data/training_data/training_data_resized/12318.png
# Resized and saved: data/training_data/training_data_resized/7130.png
# Resized and saved: data/training_data/training_data_resized/8203.png
# Resized and saved: data/training_data/training_data_resized/13006.png
# Resized and saved: data/training_data/training_data_resized/1541.png
# Resized and saved: data/training_data/training_data_resized/2048.png
# Resized and saved: data/training_data/training_data_resized/5727.png
# Resized and saved: data/training_data/training_data_resized/4439.png
# Resized and saved: data/training_data/training_data_resized/3356.png
# Resized and saved: data/training_data/training_data_resized/11611.png
# Resized and saved: data/training_data/training_data_resized/10080.png
# Resized and saved: data/training_data/training_data_resized/3801.png
# Resized and saved: data/training_data/training_data_resized/9492.png
# Resized and saved: data/training_data/training_data_resized/13589.png
# Resized and saved: data/training_data/training_data_resized/8954.png
# Resized and saved: data/training_data/training_data_resized/6979.png
# Resized and saved: data/training_data/training_data_resized/12697.png
# Resized and saved: data/training_data/training_data_resized/1970.png
# Resized and saved: data/training_data/training_data_resized/4808.png
# Resized and saved: data/training_data/training_data_resized/1964.png
# Resized and saved: data/training_data/training_data_resized/228.png
# Resized and saved: data/training_data/training_data_resized/9486.png
# Resized and saved: data/training_data/training_data_resized/8940.png
# Resized and saved: data/training_data/training_data_resized/12683.png
# Resized and saved: data/training_data/training_data_resized/8798.png
# Resized and saved: data/training_data/training_data_resized/10094.png
# Resized and saved: data/training_data/training_data_resized/3815.png
# Resized and saved: data/training_data/training_data_resized/12873.png
# Resized and saved: data/training_data/training_data_resized/8968.png
# Resized and saved: data/training_data/training_data_resized/566.png
# Resized and saved: data/training_data/training_data_resized/6945.png
# Resized and saved: data/training_data/training_data_resized/7483.png
# Resized and saved: data/training_data/training_data_resized/5294.png
# Resized and saved: data/training_data/training_data_resized/4834.png
# Resized and saved: data/training_data/training_data_resized/3183.png
# Resized and saved: data/training_data/training_data_resized/10902.png
# Resized and saved: data/training_data/training_data_resized/1794.png
# Resized and saved: data/training_data/training_data_resized/200.png
# Resized and saved: data/training_data/training_data_resized/1958.png
# Resized and saved: data/training_data/training_data_resized/214.png
# Resized and saved: data/training_data/training_data_resized/1780.png
# Resized and saved: data/training_data/training_data_resized/4820.png
# Resized and saved: data/training_data/training_data_resized/2289.png
# Resized and saved: data/training_data/training_data_resized/3197.png
# Resized and saved: data/training_data/training_data_resized/10916.png
# Resized and saved: data/training_data/training_data_resized/5280.png
# Resized and saved: data/training_data/training_data_resized/3829.png
# Resized and saved: data/training_data/training_data_resized/12867.png
# Resized and saved: data/training_data/training_data_resized/6789.png
# Resized and saved: data/training_data/training_data_resized/572.png
# Resized and saved: data/training_data/training_data_resized/6951.png
# Resized and saved: data/training_data/training_data_resized/7497.png
# Resized and saved: data/training_data/training_data_resized/12654.png
# Resized and saved: data/training_data/training_data_resized/6762.png
# Resized and saved: data/training_data/training_data_resized/9451.png
# Resized and saved: data/training_data/training_data_resized/599.png
# Resized and saved: data/training_data/training_data_resized/8997.png
# Resized and saved: data/training_data/training_data_resized/2504.png
# Resized and saved: data/training_data/training_data_resized/10043.png
# Resized and saved: data/training_data/training_data_resized/4175.png
# Resized and saved: data/training_data/training_data_resized/4613.png
# Resized and saved: data/training_data/training_data_resized/2262.png
# Resized and saved: data/training_data/training_data_resized/10725.png
# Resized and saved: data/training_data/training_data_resized/6004.png
# Resized and saved: data/training_data/training_data_resized/9337.png
# Resized and saved: data/training_data/training_data_resized/8029.png
# Resized and saved: data/training_data/training_data_resized/12132.png
# Resized and saved: data/training_data/training_data_resized/13238.png
# Resized and saved: data/training_data/training_data_resized/6010.png
# Resized and saved: data/training_data/training_data_resized/9323.png
# Resized and saved: data/training_data/training_data_resized/12126.png
# Resized and saved: data/training_data/training_data_resized/3168.png
# Resized and saved: data/training_data/training_data_resized/4607.png
# Resized and saved: data/training_data/training_data_resized/5519.png
# Resized and saved: data/training_data/training_data_resized/2276.png
# Resized and saved: data/training_data/training_data_resized/10731.png
# Resized and saved: data/training_data/training_data_resized/2510.png
# Resized and saved: data/training_data/training_data_resized/10057.png
# Resized and saved: data/training_data/training_data_resized/4161.png
# Resized and saved: data/training_data/training_data_resized/11349.png
# Resized and saved: data/training_data/training_data_resized/12640.png
# Resized and saved: data/training_data/training_data_resized/7468.png
# Resized and saved: data/training_data/training_data_resized/6776.png
# Resized and saved: data/training_data/training_data_resized/12898.png
# Resized and saved: data/training_data/training_data_resized/9445.png
# Resized and saved: data/training_data/training_data_resized/8983.png
# Resized and saved: data/training_data/training_data_resized/1019.png
# Resized and saved: data/training_data/training_data_resized/2538.png
# Resized and saved: data/training_data/training_data_resized/5257.png
# Resized and saved: data/training_data/training_data_resized/4149.png
# Resized and saved: data/training_data/training_data_resized/11361.png
# Resized and saved: data/training_data/training_data_resized/3626.png
# Resized and saved: data/training_data/training_data_resized/12668.png
# Resized and saved: data/training_data/training_data_resized/6986.png
# Resized and saved: data/training_data/training_data_resized/8773.png
# Resized and saved: data/training_data/training_data_resized/7440.png
# Resized and saved: data/training_data/training_data_resized/1031.png
# Resized and saved: data/training_data/training_data_resized/13576.png
# Resized and saved: data/training_data/training_data_resized/1757.png
# Resized and saved: data/training_data/training_data_resized/13210.png
# Resized and saved: data/training_data/training_data_resized/6038.png
# Resized and saved: data/training_data/training_data_resized/8015.png
# Resized and saved: data/training_data/training_data_resized/7326.png
# Resized and saved: data/training_data/training_data_resized/11407.png
# Resized and saved: data/training_data/training_data_resized/3140.png
# Resized and saved: data/training_data/training_data_resized/5531.png
# Resized and saved: data/training_data/training_data_resized/10719.png
# Resized and saved: data/training_data/training_data_resized/11413.png
# Resized and saved: data/training_data/training_data_resized/3154.png
# Resized and saved: data/training_data/training_data_resized/5525.png
# Resized and saved: data/training_data/training_data_resized/1743.png
# Resized and saved: data/training_data/training_data_resized/13204.png
# Resized and saved: data/training_data/training_data_resized/8001.png
# Resized and saved: data/training_data/training_data_resized/7332.png
# Resized and saved: data/training_data/training_data_resized/6992.png
# Resized and saved: data/training_data/training_data_resized/8767.png
# Resized and saved: data/training_data/training_data_resized/7454.png
# Resized and saved: data/training_data/training_data_resized/9479.png
# Resized and saved: data/training_data/training_data_resized/1025.png
# Resized and saved: data/training_data/training_data_resized/13562.png
# Resized and saved: data/training_data/training_data_resized/5243.png
# Resized and saved: data/training_data/training_data_resized/11375.png
# Resized and saved: data/training_data/training_data_resized/3632.png
# Resized and saved: data/training_data/training_data_resized/7333.png
# Resized and saved: data/training_data/training_data_resized/8000.png
# Resized and saved: data/training_data/training_data_resized/13205.png
# Resized and saved: data/training_data/training_data_resized/1742.png
# Resized and saved: data/training_data/training_data_resized/5524.png
# Resized and saved: data/training_data/training_data_resized/3155.png
# Resized and saved: data/training_data/training_data_resized/11412.png
# Resized and saved: data/training_data/training_data_resized/3633.png
# Resized and saved: data/training_data/training_data_resized/11374.png
# Resized and saved: data/training_data/training_data_resized/5242.png
# Resized and saved: data/training_data/training_data_resized/13563.png
# Resized and saved: data/training_data/training_data_resized/1024.png
# Resized and saved: data/training_data/training_data_resized/9478.png
# Resized and saved: data/training_data/training_data_resized/7455.png
# Resized and saved: data/training_data/training_data_resized/8766.png
# Resized and saved: data/training_data/training_data_resized/6993.png
# Resized and saved: data/training_data/training_data_resized/13577.png
# Resized and saved: data/training_data/training_data_resized/1030.png
# Resized and saved: data/training_data/training_data_resized/7441.png
# Resized and saved: data/training_data/training_data_resized/8772.png
# Resized and saved: data/training_data/training_data_resized/12669.png
# Resized and saved: data/training_data/training_data_resized/6987.png
# Resized and saved: data/training_data/training_data_resized/3627.png
# Resized and saved: data/training_data/training_data_resized/11360.png
# Resized and saved: data/training_data/training_data_resized/4148.png
# Resized and saved: data/training_data/training_data_resized/5256.png
# Resized and saved: data/training_data/training_data_resized/2539.png
# Resized and saved: data/training_data/training_data_resized/10718.png
# Resized and saved: data/training_data/training_data_resized/5530.png
# Error processing data/training_data/training_data/3141.png: cannot identify image file '/Users/scottunderdown/Desktop/MLiS_2/data/training_data/training_data/3141.png'
# Resized and saved: data/training_data/training_data_resized/11406.png
# Resized and saved: data/training_data/training_data_resized/7327.png
# Resized and saved: data/training_data/training_data_resized/8014.png
# Resized and saved: data/training_data/training_data_resized/6039.png
# Resized and saved: data/training_data/training_data_resized/13211.png
# Resized and saved: data/training_data/training_data_resized/1756.png
# Resized and saved: data/training_data/training_data_resized/10730.png
# Resized and saved: data/training_data/training_data_resized/2277.png
# Resized and saved: data/training_data/training_data_resized/5518.png
# Resized and saved: data/training_data/training_data_resized/4606.png
# Resized and saved: data/training_data/training_data_resized/3169.png
# Resized and saved: data/training_data/training_data_resized/12127.png
# Resized and saved: data/training_data/training_data_resized/9322.png
# Resized and saved: data/training_data/training_data_resized/6011.png
# Resized and saved: data/training_data/training_data_resized/13239.png
# Resized and saved: data/training_data/training_data_resized/8982.png
# Resized and saved: data/training_data/training_data_resized/1018.png
# Resized and saved: data/training_data/training_data_resized/9444.png
# Resized and saved: data/training_data/training_data_resized/6777.png
# Resized and saved: data/training_data/training_data_resized/12899.png
# Resized and saved: data/training_data/training_data_resized/7469.png
# Resized and saved: data/training_data/training_data_resized/12641.png
# Resized and saved: data/training_data/training_data_resized/11348.png
# Resized and saved: data/training_data/training_data_resized/4160.png
# Resized and saved: data/training_data/training_data_resized/10056.png
# Resized and saved: data/training_data/training_data_resized/2511.png
# Resized and saved: data/training_data/training_data_resized/4174.png
# Resized and saved: data/training_data/training_data_resized/10042.png
# Resized and saved: data/training_data/training_data_resized/2505.png
# Resized and saved: data/training_data/training_data_resized/598.png
# Resized and saved: data/training_data/training_data_resized/8996.png
# Resized and saved: data/training_data/training_data_resized/9450.png
# Resized and saved: data/training_data/training_data_resized/6763.png
# Resized and saved: data/training_data/training_data_resized/12655.png
# Resized and saved: data/training_data/training_data_resized/12133.png
# Resized and saved: data/training_data/training_data_resized/8028.png
# Resized and saved: data/training_data/training_data_resized/9336.png
# Resized and saved: data/training_data/training_data_resized/6005.png
# Resized and saved: data/training_data/training_data_resized/10724.png
# Resized and saved: data/training_data/training_data_resized/2263.png
# Resized and saved: data/training_data/training_data_resized/4612.png
# Resized and saved: data/training_data/training_data_resized/10917.png
# Resized and saved: data/training_data/training_data_resized/3196.png
# Resized and saved: data/training_data/training_data_resized/2288.png
# Resized and saved: data/training_data/training_data_resized/4821.png
# Resized and saved: data/training_data/training_data_resized/1781.png
# Resized and saved: data/training_data/training_data_resized/215.png
# Resized and saved: data/training_data/training_data_resized/1959.png
# Resized and saved: data/training_data/training_data_resized/7496.png
# Resized and saved: data/training_data/training_data_resized/6950.png
# Resized and saved: data/training_data/training_data_resized/573.png
# Resized and saved: data/training_data/training_data_resized/12866.png
# Resized and saved: data/training_data/training_data_resized/6788.png
# Resized and saved: data/training_data/training_data_resized/3828.png
# Resized and saved: data/training_data/training_data_resized/5281.png
# Resized and saved: data/training_data/training_data_resized/5295.png
# Resized and saved: data/training_data/training_data_resized/7482.png
# Resized and saved: data/training_data/training_data_resized/6944.png
# Resized and saved: data/training_data/training_data_resized/8969.png
# Resized and saved: data/training_data/training_data_resized/567.png
# Resized and saved: data/training_data/training_data_resized/12872.png
# Resized and saved: data/training_data/training_data_resized/201.png
# Resized and saved: data/training_data/training_data_resized/1795.png
# Resized and saved: data/training_data/training_data_resized/10903.png
# Resized and saved: data/training_data/training_data_resized/3182.png
# Resized and saved: data/training_data/training_data_resized/4835.png
# Resized and saved: data/training_data/training_data_resized/229.png
# Resized and saved: data/training_data/training_data_resized/1965.png
# Resized and saved: data/training_data/training_data_resized/3814.png
# Resized and saved: data/training_data/training_data_resized/10095.png
# Resized and saved: data/training_data/training_data_resized/8799.png
# Resized and saved: data/training_data/training_data_resized/12682.png
# Resized and saved: data/training_data/training_data_resized/8941.png
# Resized and saved: data/training_data/training_data_resized/9487.png
# Resized and saved: data/training_data/training_data_resized/6978.png
# Resized and saved: data/training_data/training_data_resized/12696.png
# Resized and saved: data/training_data/training_data_resized/8955.png
# Resized and saved: data/training_data/training_data_resized/13588.png
# Resized and saved: data/training_data/training_data_resized/9493.png
# Resized and saved: data/training_data/training_data_resized/3800.png
# Resized and saved: data/training_data/training_data_resized/10081.png
# Resized and saved: data/training_data/training_data_resized/4809.png
# Resized and saved: data/training_data/training_data_resized/1971.png
# Resized and saved: data/training_data/training_data_resized/8564.png
# Resized and saved: data/training_data/training_data_resized/7657.png
# Resized and saved: data/training_data/training_data_resized/6549.png
# Resized and saved: data/training_data/training_data_resized/1226.png
# Resized and saved: data/training_data/training_data_resized/13761.png
# Resized and saved: data/training_data/training_data_resized/10268.png
# Resized and saved: data/training_data/training_data_resized/5040.png
# Resized and saved: data/training_data/training_data_resized/11176.png
# Resized and saved: data/training_data/training_data_resized/3431.png
# Resized and saved: data/training_data/training_data_resized/11610.png
# Resized and saved: data/training_data/training_data_resized/3357.png
# Resized and saved: data/training_data/training_data_resized/4438.png
# Resized and saved: data/training_data/training_data_resized/5726.png
# Resized and saved: data/training_data/training_data_resized/2049.png
# Resized and saved: data/training_data/training_data_resized/1540.png
# Resized and saved: data/training_data/training_data_resized/13007.png
# Resized and saved: data/training_data/training_data_resized/8202.png
# Resized and saved: data/training_data/training_data_resized/7131.png
# Resized and saved: data/training_data/training_data_resized/12319.png
# Resized and saved: data/training_data/training_data_resized/1554.png
# Resized and saved: data/training_data/training_data_resized/13013.png
# Resized and saved: data/training_data/training_data_resized/9108.png
# Resized and saved: data/training_data/training_data_resized/8216.png
# Resized and saved: data/training_data/training_data_resized/7125.png
# Resized and saved: data/training_data/training_data_resized/11604.png
# Resized and saved: data/training_data/training_data_resized/3343.png
# Resized and saved: data/training_data/training_data_resized/5732.png
# Resized and saved: data/training_data/training_data_resized/5054.png
# Resized and saved: data/training_data/training_data_resized/11162.png
# Resized and saved: data/training_data/training_data_resized/3425.png
# Resized and saved: data/training_data/training_data_resized/8570.png
# Resized and saved: data/training_data/training_data_resized/7643.png
# Resized and saved: data/training_data/training_data_resized/1232.png
# Resized and saved: data/training_data/training_data_resized/13775.png
# Resized and saved: data/training_data/training_data_resized/2713.png
# Resized and saved: data/training_data/training_data_resized/10254.png
# Resized and saved: data/training_data/training_data_resized/4362.png
# Resized and saved: data/training_data/training_data_resized/12443.png
# Resized and saved: data/training_data/training_data_resized/956.png
# Resized and saved: data/training_data/training_data_resized/8558.png
# Resized and saved: data/training_data/training_data_resized/6575.png
# Resized and saved: data/training_data/training_data_resized/9646.png
# Resized and saved: data/training_data/training_data_resized/6213.png
# Resized and saved: data/training_data/training_data_resized/9120.png
# Resized and saved: data/training_data/training_data_resized/12325.png
# Resized and saved: data/training_data/training_data_resized/4404.png
# Resized and saved: data/training_data/training_data_resized/2075.png
# Resized and saved: data/training_data/training_data_resized/10532.png
# Resized and saved: data/training_data/training_data_resized/11638.png
# Resized and saved: data/training_data/training_data_resized/4410.png
# Resized and saved: data/training_data/training_data_resized/2061.png
# Resized and saved: data/training_data/training_data_resized/10526.png
# Resized and saved: data/training_data/training_data_resized/1568.png
# Resized and saved: data/training_data/training_data_resized/6207.png
# Resized and saved: data/training_data/training_data_resized/9134.png
# Resized and saved: data/training_data/training_data_resized/7119.png
# Resized and saved: data/training_data/training_data_resized/12331.png
# Resized and saved: data/training_data/training_data_resized/12457.png
# Resized and saved: data/training_data/training_data_resized/942.png
# Resized and saved: data/training_data/training_data_resized/6561.png
# Resized and saved: data/training_data/training_data_resized/9652.png
# Resized and saved: data/training_data/training_data_resized/13749.png
# Resized and saved: data/training_data/training_data_resized/2707.png
# Resized and saved: data/training_data/training_data_resized/10240.png
# Resized and saved: data/training_data/training_data_resized/5068.png
# Resized and saved: data/training_data/training_data_resized/4376.png
# Resized and saved: data/training_data/training_data_resized/3419.png
# Resized and saved: data/training_data/training_data_resized/2934.png
# Resized and saved: data/training_data/training_data_resized/5083.png
# Resized and saved: data/training_data/training_data_resized/771.png
# Resized and saved: data/training_data/training_data_resized/9861.png
# Resized and saved: data/training_data/training_data_resized/7694.png
# Resized and saved: data/training_data/training_data_resized/1583.png
# Resized and saved: data/training_data/training_data_resized/3394.png
# Resized and saved: data/training_data/training_data_resized/5929.png
# Resized and saved: data/training_data/training_data_resized/3380.png
# Resized and saved: data/training_data/training_data_resized/1597.png
# Resized and saved: data/training_data/training_data_resized/765.png
# Resized and saved: data/training_data/training_data_resized/7858.png
# Resized and saved: data/training_data/training_data_resized/9875.png
# Resized and saved: data/training_data/training_data_resized/7680.png
# Resized and saved: data/training_data/training_data_resized/4389.png
# Resized and saved: data/training_data/training_data_resized/2920.png
# Resized and saved: data/training_data/training_data_resized/5097.png
# Resized and saved: data/training_data/training_data_resized/9685.png
# Resized and saved: data/training_data/training_data_resized/7870.png
# Resized and saved: data/training_data/training_data_resized/12480.png
# Resized and saved: data/training_data/training_data_resized/995.png
# Resized and saved: data/training_data/training_data_resized/2908.png
# Resized and saved: data/training_data/training_data_resized/11189.png
# Resized and saved: data/training_data/training_data_resized/10297.png
# Resized and saved: data/training_data/training_data_resized/11837.png
# Resized and saved: data/training_data/training_data_resized/5901.png
# Resized and saved: data/training_data/training_data_resized/11823.png
# Resized and saved: data/training_data/training_data_resized/5915.png
# Resized and saved: data/training_data/training_data_resized/10283.png
# Resized and saved: data/training_data/training_data_resized/9691.png
# Resized and saved: data/training_data/training_data_resized/7864.png
# Resized and saved: data/training_data/training_data_resized/759.png
# Resized and saved: data/training_data/training_data_resized/12494.png
# Resized and saved: data/training_data/training_data_resized/9849.png
# Resized and saved: data/training_data/training_data_resized/981.png
# Resized and saved: data/training_data/training_data_resized/1352.png
# Resized and saved: data/training_data/training_data_resized/13615.png
# Resized and saved: data/training_data/training_data_resized/8410.png
# Resized and saved: data/training_data/training_data_resized/7723.png
# Resized and saved: data/training_data/training_data_resized/11002.png
# Resized and saved: data/training_data/training_data_resized/3545.png
# Resized and saved: data/training_data/training_data_resized/2883.png
# Resized and saved: data/training_data/training_data_resized/5134.png
# Resized and saved: data/training_data/training_data_resized/5652.png
# Resized and saved: data/training_data/training_data_resized/11764.png
# Resized and saved: data/training_data/training_data_resized/3223.png
# Resized and saved: data/training_data/training_data_resized/8376.png
# Resized and saved: data/training_data/training_data_resized/7045.png
# Resized and saved: data/training_data/training_data_resized/9068.png
# Resized and saved: data/training_data/training_data_resized/1434.png
# Resized and saved: data/training_data/training_data_resized/13173.png
# Resized and saved: data/training_data/training_data_resized/12279.png
# Resized and saved: data/training_data/training_data_resized/8362.png
# Resized and saved: data/training_data/training_data_resized/7051.png
# Resized and saved: data/training_data/training_data_resized/1420.png
# Resized and saved: data/training_data/training_data_resized/13167.png
# Resized and saved: data/training_data/training_data_resized/2129.png
# Resized and saved: data/training_data/training_data_resized/5646.png
# Resized and saved: data/training_data/training_data_resized/4558.png
# Resized and saved: data/training_data/training_data_resized/11770.png
# Resized and saved: data/training_data/training_data_resized/3237.png
# Resized and saved: data/training_data/training_data_resized/11016.png
# Resized and saved: data/training_data/training_data_resized/3551.png
# Resized and saved: data/training_data/training_data_resized/2897.png
# Resized and saved: data/training_data/training_data_resized/5120.png
# Resized and saved: data/training_data/training_data_resized/10308.png
# Resized and saved: data/training_data/training_data_resized/1346.png
# Resized and saved: data/training_data/training_data_resized/13601.png
# Resized and saved: data/training_data/training_data_resized/6429.png
# Resized and saved: data/training_data/training_data_resized/8404.png
# Resized and saved: data/training_data/training_data_resized/7737.png
# Resized and saved: data/training_data/training_data_resized/3579.png
# Resized and saved: data/training_data/training_data_resized/4216.png
# Resized and saved: data/training_data/training_data_resized/5108.png
# Resized and saved: data/training_data/training_data_resized/2667.png
# Resized and saved: data/training_data/training_data_resized/10320.png
# Resized and saved: data/training_data/training_data_resized/13629.png
# ...
# Resized and saved: data/training_data/training_data_resized/11191.png
# Resized and saved: data/training_data/training_data_resized/2910.png
# Resized and saved: data/training_data/training_data_resized/11185.png
# Resized and saved: data/training_data/training_data_resized/2904.png
# Resized and saved: data/training_data/training_data_resized/741.png
# Resized and saved: data/training_data/training_data_resized/13792.png
# Resized and saved: data/training_data/training_data_resized/9689.png
# Resized and saved: data/training_data/training_data_resized/999.png
# Resized and saved: data/training_data/training_data_resized/8597.png
# Resized and saved: data/training_data/training_data_resized/9851.png
# Resized and saved: data/training_data/training_data_resized/2125.png
# Resized and saved: data/training_data/training_data_resized/10462.png
# Resized and saved: data/training_data/training_data_resized/5892.png
# Resized and saved: data/training_data/training_data_resized/4554.png
# Resized and saved: data/training_data/training_data_resized/12275.png
# Resized and saved: data/training_data/training_data_resized/6343.png
# Resized and saved: data/training_data/training_data_resized/9070.png
# Resized and saved: data/training_data/training_data_resized/6425.png
# Resized and saved: data/training_data/training_data_resized/46.png
# Resized and saved: data/training_data/training_data_resized/9716.png
# Resized and saved: data/training_data/training_data_resized/12513.png
# Resized and saved: data/training_data/training_data_resized/8408.png
# Resized and saved: data/training_data/training_data_resized/806.png
# Resized and saved: data/training_data/training_data_resized/4232.png
# Resized and saved: data/training_data/training_data_resized/2643.png
# Resized and saved: data/training_data/training_data_resized/10304.png
# Resized and saved: data/training_data/training_data_resized/4226.png
# Resized and saved: data/training_data/training_data_resized/3549.png
# Resized and saved: data/training_data/training_data_resized/2657.png
# Resized and saved: data/training_data/training_data_resized/10310.png
# Resized and saved: data/training_data/training_data_resized/5138.png
# Resized and saved: data/training_data/training_data_resized/52.png
# Resized and saved: data/training_data/training_data_resized/6431.png
# Resized and saved: data/training_data/training_data_resized/9702.png
# Resized and saved: data/training_data/training_data_resized/13619.png
# Resized and saved: data/training_data/training_data_resized/12507.png
# Resized and saved: data/training_data/training_data_resized/812.png
# Resized and saved: data/training_data/training_data_resized/7049.png
# Resized and saved: data/training_data/training_data_resized/12261.png
# Resized and saved: data/training_data/training_data_resized/1438.png
# Resized and saved: data/training_data/training_data_resized/6357.png
# Resized and saved: data/training_data/training_data_resized/9064.png
# Resized and saved: data/training_data/training_data_resized/2131.png
# Resized and saved: data/training_data/training_data_resized/10476.png
# Resized and saved: data/training_data/training_data_resized/5886.png
# Resized and saved: data/training_data/training_data_resized/11768.png
# Resized and saved: data/training_data/training_data_resized/4540.png
# Resized and saved: data/training_data/training_data_resized/8352.png
# Resized and saved: data/training_data/training_data_resized/7061.png
# Resized and saved: data/training_data/training_data_resized/12249.png
# Resized and saved: data/training_data/training_data_resized/1410.png
# Resized and saved: data/training_data/training_data_resized/184.png
# Resized and saved: data/training_data/training_data_resized/13157.png
# Resized and saved: data/training_data/training_data_resized/11998.png
# Resized and saved: data/training_data/training_data_resized/5676.png
# Resized and saved: data/training_data/training_data_resized/2119.png
# Resized and saved: data/training_data/training_data_resized/11740.png
# Resized and saved: data/training_data/training_data_resized/3207.png
# Resized and saved: data/training_data/training_data_resized/4568.png
# Resized and saved: data/training_data/training_data_resized/11026.png
# Resized and saved: data/training_data/training_data_resized/3561.png
# Resized and saved: data/training_data/training_data_resized/10338.png
# Resized and saved: data/training_data/training_data_resized/5110.png
# Resized and saved: data/training_data/training_data_resized/6419.png
# Resized and saved: data/training_data/training_data_resized/1376.png
# Resized and saved: data/training_data/training_data_resized/13631.png
# Resized and saved: data/training_data/training_data_resized/8434.png
# Resized and saved: data/training_data/training_data_resized/7707.png
# Resized and saved: data/training_data/training_data_resized/1362.png
# Resized and saved: data/training_data/training_data_resized/13625.png
# Resized and saved: data/training_data/training_data_resized/8420.png
# Resized and saved: data/training_data/training_data_resized/7713.png
# Resized and saved: data/training_data/training_data_resized/11032.png
# Resized and saved: data/training_data/training_data_resized/3575.png
# Resized and saved: data/training_data/training_data_resized/5104.png
# Resized and saved: data/training_data/training_data_resized/5662.png
# Resized and saved: data/training_data/training_data_resized/11754.png
# Resized and saved: data/training_data/training_data_resized/3213.png
# Resized and saved: data/training_data/training_data_resized/8346.png
# Resized and saved: data/training_data/training_data_resized/7075.png
# Resized and saved: data/training_data/training_data_resized/190.png
# Resized and saved: data/training_data/training_data_resized/1404.png
# Resized and saved: data/training_data/training_data_resized/13143.png
# Resized and saved: data/training_data/training_data_resized/9058.png
# Resized and saved: data/training_data/training_data_resized/6380.png
# Resized and saved: data/training_data/training_data_resized/5851.png
# Resized and saved: data/training_data/training_data_resized/4597.png
# Resized and saved: data/training_data/training_data_resized/5689.png
# Resized and saved: data/training_data/training_data_resized/11967.png
# Resized and saved: data/training_data/training_data_resized/2680.png
# Resized and saved: data/training_data/training_data_resized/2858.png
# Resized and saved: data/training_data/training_data_resized/85.png
# Resized and saved: data/training_data/training_data_resized/7920.png
# Resized and saved: data/training_data/training_data_resized/1389.png
# Resized and saved: data/training_data/training_data_resized/9919.png
# Resized and saved: data/training_data/training_data_resized/91.png
# Resized and saved: data/training_data/training_data_resized/7934.png
# Resized and saved: data/training_data/training_data_resized/609.png
# Resized and saved: data/training_data/training_data_resized/2694.png
# Resized and saved: data/training_data/training_data_resized/5845.png
# Resized and saved: data/training_data/training_data_resized/4583.png
# Resized and saved: data/training_data/training_data_resized/11973.png
# Resized and saved: data/training_data/training_data_resized/6394.png
# Resized and saved: data/training_data/training_data_resized/11783.png
# Resized and saved: data/training_data/training_data_resized/147.png
# Resized and saved: data/training_data/training_data_resized/13194.png
# Resized and saved: data/training_data/training_data_resized/8391.png
# Resized and saved: data/training_data/training_data_resized/9931.png
# Resized and saved: data/training_data/training_data_resized/621.png
# Resized and saved: data/training_data/training_data_resized/2864.png
# Resized and saved: data/training_data/training_data_resized/2870.png
# Resized and saved: data/training_data/training_data_resized/9925.png
# Resized and saved: data/training_data/training_data_resized/635.png
# Resized and saved: data/training_data/training_data_resized/7908.png
# Resized and saved: data/training_data/training_data_resized/153.png
# Resized and saved: data/training_data/training_data_resized/13180.png
# Resized and saved: data/training_data/training_data_resized/8385.png
# Resized and saved: data/training_data/training_data_resized/11797.png
# Resized and saved: data/training_data/training_data_resized/5879.png
# Resized and saved: data/training_data/training_data_resized/10489.png
# Resized and saved: data/training_data/training_data_resized/3987.png
# Resized and saved: data/training_data/training_data_resized/10106.png
# Resized and saved: data/training_data/training_data_resized/2441.png
# Resized and saved: data/training_data/training_data_resized/11218.png
# Resized and saved: data/training_data/training_data_resized/4030.png
# Resized and saved: data/training_data/training_data_resized/7539.png
# Resized and saved: data/training_data/training_data_resized/12711.png
# Resized and saved: data/training_data/training_data_resized/1148.png
# Resized and saved: data/training_data/training_data_resized/9514.png
# Resized and saved: data/training_data/training_data_resized/6627.png
# Resized and saved: data/training_data/training_data_resized/9272.png
# Resized and saved: data/training_data/training_data_resized/6141.png
# Resized and saved: data/training_data/training_data_resized/13369.png
# Resized and saved: data/training_data/training_data_resized/12077.png
# Resized and saved: data/training_data/training_data_resized/4756.png
# Resized and saved: data/training_data/training_data_resized/3039.png
# Resized and saved: data/training_data/training_data_resized/10660.png
# Resized and saved: data/training_data/training_data_resized/2327.png
# Resized and saved: data/training_data/training_data_resized/5448.png
# Resized and saved: data/training_data/training_data_resized/4742.png
# Resized and saved: data/training_data/training_data_resized/10674.png
# Resized and saved: data/training_data/training_data_resized/2333.png
# Resized and saved: data/training_data/training_data_resized/9266.png
# Resized and saved: data/training_data/training_data_resized/6155.png
# Resized and saved: data/training_data/training_data_resized/12063.png
# Resized and saved: data/training_data/training_data_resized/8178.png
# Resized and saved: data/training_data/training_data_resized/12705.png
# Resized and saved: data/training_data/training_data_resized/9500.png
# Resized and saved: data/training_data/training_data_resized/6633.png
# Resized and saved: data/training_data/training_data_resized/3993.png
# Resized and saved: data/training_data/training_data_resized/10112.png
# Resized and saved: data/training_data/training_data_resized/2455.png
# Resized and saved: data/training_data/training_data_resized/4024.png
# Resized and saved: data/training_data/training_data_resized/7505.png
# Resized and saved: data/training_data/training_data_resized/8636.png
# Resized and saved: data/training_data/training_data_resized/13433.png
# Resized and saved: data/training_data/training_data_resized/1174.png
# Resized and saved: data/training_data/training_data_resized/9528.png
# Resized and saved: data/training_data/training_data_resized/5312.png
# Resized and saved: data/training_data/training_data_resized/3763.png
# Resized and saved: data/training_data/training_data_resized/11224.png
# Resized and saved: data/training_data/training_data_resized/10884.png
# Resized and saved: data/training_data/training_data_resized/3005.png
# Resized and saved: data/training_data/training_data_resized/11542.png
# Resized and saved: data/training_data/training_data_resized/5474.png
# Resized and saved: data/training_data/training_data_resized/13355.png
# Resized and saved: data/training_data/training_data_resized/386.png
# Resized and saved: data/training_data/training_data_resized/1612.png
# Resized and saved: data/training_data/training_data_resized/7263.png
# Resized and saved: data/training_data/training_data_resized/8150.png
# Resized and saved: data/training_data/training_data_resized/6169.png
# Resized and saved: data/training_data/training_data_resized/13341.png
# Resized and saved: data/training_data/training_data_resized/1606.png
# Resized and saved: data/training_data/training_data_resized/392.png
# Resized and saved: data/training_data/training_data_resized/7277.png
# Resized and saved: data/training_data/training_data_resized/8144.png
# Resized and saved: data/training_data/training_data_resized/10890.png
# Resized and saved: data/training_data/training_data_resized/3011.png
# Resized and saved: data/training_data/training_data_resized/11556.png
# Resized and saved: data/training_data/training_data_resized/10648.png
# Resized and saved: data/training_data/training_data_resized/5460.png
# Resized and saved: data/training_data/training_data_resized/5306.png
# Resized and saved: data/training_data/training_data_resized/2469.png
# Resized and saved: data/training_data/training_data_resized/3777.png
# Resized and saved: data/training_data/training_data_resized/11230.png
# Resized and saved: data/training_data/training_data_resized/4018.png
# Resized and saved: data/training_data/training_data_resized/7511.png
# Resized and saved: data/training_data/training_data_resized/8622.png
# Resized and saved: data/training_data/training_data_resized/12739.png
# Resized and saved: data/training_data/training_data_resized/13427.png
# Resized and saved: data/training_data/training_data_resized/1160.png
# Resized and saved: data/training_data/training_data_resized/8811.png
# Resized and saved: data/training_data/training_data_resized/3944.png
# Resized and saved: data/training_data/training_data_resized/2482.png
# Resized and saved: data/training_data/training_data_resized/4795.png
# Resized and saved: data/training_data/training_data_resized/1835.png
# Resized and saved: data/training_data/training_data_resized/6182.png
# Resized and saved: data/training_data/training_data_resized/379.png
# Resized and saved: data/training_data/training_data_resized/1821.png
# Resized and saved: data/training_data/training_data_resized/7288.png
# Resized and saved: data/training_data/training_data_resized/6196.png
# Resized and saved: data/training_data/training_data_resized/4959.png
# Resized and saved: data/training_data/training_data_resized/4781.png
# Resized and saved: data/training_data/training_data_resized/3788.png
# Resized and saved: data/training_data/training_data_resized/3950.png
# Resized and saved: data/training_data/training_data_resized/2496.png
# Resized and saved: data/training_data/training_data_resized/8805.png
# Resized and saved: data/training_data/training_data_resized/6828.png
# Resized and saved: data/training_data/training_data_resized/3978.png
# Resized and saved: data/training_data/training_data_resized/423.png
# Resized and saved: data/training_data/training_data_resized/12936.png
# Resized and saved: data/training_data/training_data_resized/6800.png
# Resized and saved: data/training_data/training_data_resized/12088.png
# Resized and saved: data/training_data/training_data_resized/8193.png
# Resized and saved: data/training_data/training_data_resized/1809.png
# Resized and saved: data/training_data/training_data_resized/13396.png
# Resized and saved: data/training_data/training_data_resized/345.png
# Resized and saved: data/training_data/training_data_resized/4971.png
# Resized and saved: data/training_data/training_data_resized/10847.png
# Resized and saved: data/training_data/training_data_resized/11581.png
# Resized and saved: data/training_data/training_data_resized/4965.png
# Resized and saved: data/training_data/training_data_resized/10853.png
# Resized and saved: data/training_data/training_data_resized/11595.png
# Resized and saved: data/training_data/training_data_resized/8187.png
# Resized and saved: data/training_data/training_data_resized/9299.png
# Resized and saved: data/training_data/training_data_resized/13382.png
# Resized and saved: data/training_data/training_data_resized/351.png
# Resized and saved: data/training_data/training_data_resized/437.png
# Resized and saved: data/training_data/training_data_resized/8839.png
# Resized and saved: data/training_data/training_data_resized/12922.png
# Resized and saved: data/training_data/training_data_resized/6814.png

# %%
import os
import numpy as np
import pandas as pd
import shutil


#! IMPORTANT !!
# make sure the training data file structure is as follows data/training_data/training_data

#! WARNING !! 
# the first part of the notebook won't work as the files are now in a different place


ignore = [4895, 3999, 8285, 10171, 3141, 3884]
#fileNames = os.listdir('data/training_data/training_data/')
meta_data = pd.read_csv('data/training_norm.csv')

categories_angle = [0.0, 0.0625, 0.125, 0.1875, 0.25, 0.3125, 0.375, 0.4375, 0.5, 0.5625, 0.625, 0.6875, 0.75, 0.8125, 0.875, 0.9375, 1.0]
# categories_speed = [0, 1]
    
# number of elements 13793
# 15% validation 85% training 
# 2069 for validation

#match number number of elements in angle categories with speed 1 to number of elements in angle categories with speed 0 


# os.makedirs(f'data/speed/0')
# os.makedirs(f'data/speed/1')
# os.makedirs(f'data/test_speed/0')
# os.makedirs(f'data/test_speed/1')


for angle in categories_angle: 
    os.makedirs(f'data/angle_resize/{angle}')
    # os.makedirs(f'data/test_angle_resize/{angle}')

angle_count = {0.0:0, 0.0625:0, 0.125:0, 0.1875:0, 0.25:0, 0.3125:0, 0.375:0, 0.4375:0, 0.5:0, 0.5625:0, 0.625:0, 0.6875:0, 0.75:0, 0.8125:0, 0.875:0, 0.9375:0, 1.0:0}
# speed_count = {0:0, 1:0}

for index, row in meta_data.iterrows():

    image_name = int(row['image_id'])
  
    if image_name not in ignore:
        
        #image_metadata = [row['angle'], row['speed']]
        
        #new_cat = categories.index(image_metadata)
        # data/training_data/training_data_resized
        
        source = f'data/training_data/training_data_resized/{image_name}.png'

        # source = f'data/training_data/training_data/{image_name}.png'
        angle = row['angle']
        # speed = int(row['speed'])

        # if np.random.random() >= 0.1:
        #     destination = f'data/test_angle/{angle}/{image_name}.png'
        #     shutil.copy(source, destination)
        #     destination = f'data/test_speed/{speed}/{image_name}.png'
        #     shutil.copy(source, destination)
        # else:
        #if angle_count[angle] < 150: 
        destination_angle = f'data/angle_resize/{angle}/{image_name}.png'
        shutil.copy(source, destination_angle) 
            #angle_count[angle]+=1
            
        #if speed_count[speed] < 3390:
        # destination_speed = f'data/speed/{speed}/{image_name}.png'
        # shutil.copy(source, destination_speed) 
            #speed_count[speed]+=1
