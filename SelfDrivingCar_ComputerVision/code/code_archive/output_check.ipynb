# %%
import pandas as pd
import tensorflow as tf
from keras import models
# Out:
# 2025-03-13 12:25:20.105091: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-13 12:25:20.360021: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-03-13 12:25:20.360064: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-03-13 12:25:20.419428: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
df = pd.read_csv('outputs.csv', index_col=False)
#df.drop(columns='Unnamed: 0', inplace=True)
#df.reset_index(drop=True)


for i in range(len(df)):
    df['image_id'].iloc[i] +=1
    
df.head()
# Out:
# /tmp/ipykernel_53445/3402130223.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image_id'].iloc[i] +=1
# /tmp/ipykernel_53445/3402130223.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image_id'].iloc[i] +=1
# /tmp/ipykernel_53445/3402130223.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['image_id'].iloc[i] +=1
# /tmp/ipykernel_53445/3402130223.py:7: SettingWithCopyWarning:
# ...

# %%
#split data into speed 0 and 1 
#go through speed 0 save every instance 
df.to_csv('submission.csv', index=False)

# %%
tests = {'this' : [0,0,0], 'is':[0,0,0], 'bullshit':[0,0,0]}
df = pd.DataFrame(tests)
df.to_csv('fuckoff.csv', index = False)

# %%
df= pd.read_csv('fuckoff.csv')
df.head()
# Out:
#    this  is  bullshit
# 0     0   0         0
# 1     0   0         0
# 2     0   0         0

# %%
model_speed = models.load_model('model_speed.model.hdf5')
model_angle = models.load_model('model_angle.model.hdf5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 model_speed = models.load_model('model_speed.model.hdf5')
#       2 model_angle = models.load_model('model_angle.model.hdf5')
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/keras/engine/input_layer.py:152, in InputLayer.__init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, type_spec, **kwargs)
# ...
