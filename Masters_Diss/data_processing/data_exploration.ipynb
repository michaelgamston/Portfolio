# %% [markdown]
# File name: data_exploration
#
# Description: A file containing light data exploration and a quick visualisation

# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv("../data/reduced_gin_data.csv")
df['Anonymised Sample Number'].unique().__len__()
df.isnull().count().sum()
# Out:
# 222733

# %%
sum(df.iloc[:,5:24].select_dtypes(include=['number']).sum())
# Out:
# 647

# %%
sum(df.iloc[:,22:24].select_dtypes(include=['number']).sum())
# Out:
# 223

# %% [markdown]
# 223 / 657 flavours are marked as either misc or LD

# %%
# for index, row in df.iloc[:,5:24].iterrows():
#     print(index,"-",row.sum())
    
df.iloc[:,6:25].sum().plot.bar()
plt.title("Distribution of Instances Across Flavours")
plt.xlabel("Flavours")
plt.ylabel("Number of Instances")
# Out:
# Text(0, 0.5, 'Number of Instances')

# %%
df[df['Coffee (F)'] == 1].__len__()
# Out:
# 2
